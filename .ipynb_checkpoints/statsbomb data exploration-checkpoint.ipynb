# %%
import pandas as pd
from mplsoccer import Pitch, VerticalPitch
import matplotlib.pyplot as plt

# %% [markdown]
# ## accessing statsbomb data from mplsoccer

# %%
from mplsoccer import Sbopen
# parser = Sbopen(dataframe=False) -> gives json as dictionary
parser = Sbopen()

# %% [markdown]
# #### competitions data

# %%
df_comp = parser.competition()
type(df_comp)
# Out:
# pandas.core.frame.DataFrame

# %%
df_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   competition_id             72 non-null     int64
#  1   season_id                  72 non-null     int64
#  2   country_name               72 non-null     object
#  3   competition_name           72 non-null     object
#  4   competition_gender         72 non-null     object
#  5   competition_youth          72 non-null     bool
#  6   competition_international  72 non-null     bool
#  7   season_name                72 non-null     object
#  8   match_updated              72 non-null     object
#  9   match_updated_360          55 non-null     object
#  10  match_available_360        9 non-null      object
#  11  match_available            72 non-null     object
# dtypes: bool(2), int64(2), object(8)
# memory usage: 5.9+ KB

# %%
pd.set_option('display.max_rows', df_comp.shape[0]+1)
df_comp
# Out:
#     competition_id  ...             match_available
# 0                9  ...  2024-05-21T03:36:44.090970
# 1                9  ...  2024-05-19T11:11:14.192381
# 2             1267  ...  2024-02-28T18:02:23.493027
# 3               16  ...  2024-05-13T13:14:25.239651
# 4               16  ...  2024-02-13T02:35:28.134882
# 5               16  ...  2024-02-13T02:37:32.205154
# 6               16  ...  2024-02-12T12:51:14.869531
# 7               16  ...  2024-02-12T12:49:54.914228
# 8               16  ...  2024-02-12T12:48:48.479157
# 9               16  ...  2024-02-12T12:47:34.340413
# 10              16  ...  2024-02-13T02:36:35.698340
# 11              16  ...  2024-02-12T12:53:03.944320
# 12              16  ...  2024-02-12T12:49:25.017694
# 13              16  ...  2024-02-13T07:02:54.657056
# 14              16  ...  2024-02-12T13:48:23.967222
# 15              16  ...  2024-02-12T13:09:19.665986
# 16              16  ...  2024-02-12T13:51:22.366380
# ...

# %% [markdown]
# #### match data

# %% [markdown]
# ###### FIFA WC 2022

# %%
df_match = parser.match(competition_id=43, season_id=106)
type(df_match)
# Out:
# pandas.core.frame.DataFrame

# %%
df_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 52 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   match_id                         64 non-null     int64
#  1   match_date                       64 non-null     datetime64[ns]
#  2   kick_off                         64 non-null     datetime64[ns]
#  3   home_score                       64 non-null     int64
#  4   away_score                       64 non-null     int64
#  5   match_status                     64 non-null     object
#  6   match_status_360                 64 non-null     object
#  7   last_updated                     64 non-null     datetime64[ns]
#  8   last_updated_360                 64 non-null     datetime64[ns]
#  9   match_week                       64 non-null     int64
#  10  competition_id                   64 non-null     int64
# ...

# %%
df_match
# Out:
#     match_id match_date  ... referee_country_id             referee_country_name
# 0    3857256 2022-12-02  ...               11.0                        Argentina
# 1    3869151 2022-12-03  ...              182.0                           Poland
# 2    3857257 2022-11-30  ...                4.0                          Algeria
# 3    3857258 2022-11-24  ...              107.0        Iran, Islamic Republic of
# 4    3857288 2022-11-26  ...               85.0                          Germany
# 5    3857267 2022-11-29  ...               78.0                           France
# 6    3869321 2022-12-09  ...              214.0                            Spain
# 7    3857287 2022-11-24  ...               78.0                           France
# 8    3869486 2022-12-10  ...               11.0                        Argentina
# 9    3869685 2022-12-18  ...              182.0                           Poland
# 10   3857260 2022-11-30  ...               68.0                          England
# ...

# %% [markdown]
# #### Lineup data

# %% [markdown]
# ###### FINAL : ARG vs FRA

# %%
df_lineup = parser.lineup(3869685)
type(df_lineup)
# Out:
# pandas.core.frame.DataFrame

# %%
df_lineup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   player_id        50 non-null     int64
#  1   player_name      50 non-null     object
#  2   player_nickname  50 non-null     object
#  3   jersey_number    50 non-null     int64
#  4   match_id         50 non-null     int64
#  5   team_id          50 non-null     int64
#  6   team_name        50 non-null     object
#  7   country_id       50 non-null     int64
#  8   country_name     50 non-null     object
# dtypes: int64(5), object(4)
# memory usage: 3.6+ KB

# %%
df_lineup
# Out:
#     player_id                      player_name  ... country_id  country_name
# 0        2972                    Marcus Thuram  ...         78        France
# 1        3009             Kylian Mbappé Lottin  ...         78        France
# 2        3026                    Adrien Rabiot  ...         78        France
# 3        3099                      Hugo Lloris  ...         78        France
# 4        3379                  Alphonse Areola  ...         78        France
# 5        3543                   Steve Mandanda  ...         78        France
# 6        3604                   Olivier Giroud  ...         78        France
# 7        4445                     Jules Koundé  ...         78        France
# 8        5476                  Benjamin Pavard  ...         78        France
# 9        5477                  Ousmane Dembélé  ...         78        France
# 10       5485                   Raphaël Varane  ...         78        France
# ...

# %% [markdown]
# #### Event data

# %%
df_event, df_related, df_freeze, df_tactics = parser.event(3869685)
type(df_event)
# Out:
# /Users/iamsrk/anaconda3/lib/python3.11/site-packages/mplsoccer/statsbomb.py:513: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['timestamp'] = pd.to_datetime(df['timestamp']).dt.time
# pandas.core.frame.DataFrame

# %%
type(df_event)
# Out:
# pandas.core.frame.DataFrame

# %%
df_event.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4407 entries, 0 to 4406
# Data columns (total 76 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              4407 non-null   object
#  1   index                           4407 non-null   int64
#  2   period                          4407 non-null   int64
#  3   timestamp                       4407 non-null   object
#  4   minute                          4407 non-null   int64
#  5   second                          4407 non-null   int64
#  6   possession                      4407 non-null   int64
#  7   duration                        3293 non-null   float64
#  8   match_id                        4407 non-null   int64
#  9   type_id                         4407 non-null   int64
#  10  type_name                       4407 non-null   object
#  11  possession_team_id              4407 non-null   int64
# ...

# %%
df_related.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7956 entries, 0 to 6047
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   match_id           7956 non-null   int64
#  1   id                 7956 non-null   object
#  2   index              7956 non-null   int64
#  3   type_name          7956 non-null   object
#  4   id_related         7956 non-null   object
#  5   index_related      7956 non-null   int64
#  6   type_name_related  7956 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 497.2+ KB

# %%
df_freeze.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358 entries, 0 to 357
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   teammate         358 non-null    bool
#  1   match_id         358 non-null    int64
#  2   id               358 non-null    object
#  3   x                358 non-null    float64
#  4   y                358 non-null    float64
#  5   player_id        358 non-null    int64
#  6   player_name      358 non-null    object
#  7   position_id      358 non-null    int64
#  8   position_name    358 non-null    object
#  9   event_freeze_id  358 non-null    int64
# dtypes: bool(1), float64(2), int64(4), object(3)
# memory usage: 25.7+ KB

# %%
df_tactics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   jersey_number     99 non-null     int64
#  1   match_id          99 non-null     int64
#  2   id                99 non-null     object
#  3   player_id         99 non-null     int64
#  4   player_name       99 non-null     object
#  5   position_id       99 non-null     int64
#  6   position_name     99 non-null     object
#  7   event_tactics_id  99 non-null     int64
# dtypes: int64(5), object(3)
# memory usage: 6.3+ KB

# %%
df_event.head()
# Out:
#                                      id  ...  bad_behaviour_card_name
# 0  0584ee21-e3dd-4d9f-95a0-5b5e84be25c3  ...                      NaN
# 1  b32679f8-942e-4122-96a2-015caf75e628  ...                      NaN
# 2  954f6855-de22-46a2-8d09-6fe94eec2b9b  ...                      NaN
# 3  6404a8e8-afaf-489d-b65e-173a237ffed5  ...                      NaN
# 4  f651a6c4-55e3-4e0f-a178-59414ba83d6a  ...                      NaN
#
# [5 rows x 76 columns]

# %% [markdown]
# #### 360 data

# %%
df_frame, df_visible = parser.frame(3869685)
type(df_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
df_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61451 entries, 0 to 61450
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   teammate  61451 non-null  bool
#  1   actor     61451 non-null  bool
#  2   keeper    61451 non-null  bool
#  3   match_id  61451 non-null  int64
#  4   id        61451 non-null  object
#  5   x         61451 non-null  float64
#  6   y         61451 non-null  float64
# dtypes: bool(3), float64(2), int64(1), object(1)
# memory usage: 2.1+ MB

# %%
df_visible.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   match_id      3683 non-null   int64
#  1   id            3683 non-null   object
#  2   visible_area  3683 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 86.4+ KB

# %%
df_frame.head()
# Out:
#    teammate  actor  ...          x          y
# 0      True  False  ...  39.216957  44.778613
# 1      True  False  ...  39.223561  29.496847
# 2      True  False  ...  42.576673  67.523741
# 3      True  False  ...  46.549120  12.613254
# 4      True  False  ...  47.798306  43.130706
#
# [5 rows x 7 columns]

# %%
pitch = Pitch(pitch_type='statsbomb', corner_arcs=True, goal_type='box', pitch_color='grass', line_color='white')
fig, ax = pitch.draw()
